# %% [markdown]
# # Classifying

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
cones = Table().with_columns(
    'Flavor', make_array('strawberry', 'chocolate', 'chocolate', 'strawberry', 'chocolate'),
    'Price', make_array(3.55, 4.75, 6.55, 5.25, 5.25)
)
cones
# Out:
# Flavor     | Price
# strawberry | 3.55
# chocolate  | 4.75
# chocolate  | 6.55
# strawberry | 5.25
# chocolate  | 5.25

# %%
# Default behavior is to count the number of 
# occurrences of each category
cones.group('Flavor')
# Out:
# Flavor     | count
# chocolate  | 3
# strawberry | 2

# %%
# Optionally, you can specify any function you want to see a different 
# characteristic of the categories.
# This computes the most expensive ice cream in each category
cones.group('Flavor', max)
# Out:
# Flavor     | Price max
# chocolate  | 6.55
# strawberry | 5.25

# %%
# This computes the average of all prices in the category
cones.group('Flavor', np.average)
# Out:
# Flavor     | Price average
# chocolate  | 5.51667
# strawberry | 4.4

# %%
nba = Table.read_table('nba_salaries.csv')
nba
# Out:
# rank | name             | position | team                   | salary   | season
# 1    | Shaquille O'Neal | C        | Los Angeles Lakers     | 17142000 | 2000
# 2    | Kevin Garnett    | PF       | Minnesota Timberwolves | 16806000 | 2000
# 3    | Alonzo Mourning  | C        | Miami Heat             | 15004000 | 2000
# 4    | Juwan Howard     | PF       | Washington Wizards     | 15000000 | 2000
# 5    | Scottie Pippen   | SF       | Portland Trail Blazers | 14795000 | 2000
# 6    | Karl Malone      | PF       | Utah Jazz              | 14000000 | 2000
# 7    | Larry Johnson    | F        | New York Knicks        | 11910000 | 2000
# 8    | Gary Payton      | PG       | Seattle SuperSonics    | 11020000 | 2000
# 9    | Rasheed Wallace  | PF       | Portland Trail Blazers | 10800000 | 2000
# 10   | Shawn Kemp       | C        | Cleveland Cavaliers    | 10780000 | 2000
# ... (9446 rows omitted)

# %% [markdown]
# # Practice 1
# Find the total amount of money each team paid out in salaries in the year 2000.
# - Select only the rows pertaining to the year 2000.
# - Select only the columns relevant to your calculation.
# - Group in such a way that computes the requested.

# %%
nba_2000 = nba.where('season', 2000).select('team', 'salary')
salary_by_team = nba_2000.group('team', sum).sort('salary sum', descending = True)
salary_by_team.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>team</th> <th>salary sum</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Portland Trail Blazers</td> <td>49423000  </td>
#         </tr>
#         <tr>
#             <td>Los Angeles Lakers    </td> <td>40565000  </td>
#         </tr>
#         <tr>
#             <td>Phoenix Suns          </td> <td>39262000  </td>
#         </tr>
#         <tr>
#             <td>Philadelphia 76ers    </td> <td>36748000  </td>
#         </tr>
#         <tr>
#             <td>New York Knicks       </td> <td>34960000  </td>
#         </tr>
#         <tr>
#             <td>Minnesota Timberwolves</td> <td>33478000  </td>
#         </tr>
#         <tr>
#             <td>Milwaukee Bucks       </td> <td>30736000  </td>
#         </tr>
#         <tr>
#             <td>Vancouver Grizzlies   </td> <td>28951000  </td>
#         </tr>
#         <tr>
# ...

# %% [markdown]
# # Practice 2
# Find the average salary earned by players in each position in the year 2000. (For example, the row with position 'C' contains the average salary paid to all centers across all teams in the year 2000.)

# %%
nba_position_salary= nba.where('season', 2000).select('position', 'salary')
salary_by_position = nba_position_salary.group('position', np.average)
salary_by_position
# Out:
# position | salary average
# C        | 5.49811e+06
# F        | 3.26657e+06
# G        | 2.21267e+06
# PF       | 5.24797e+06
# PG       | 4.79082e+06
# SF       | 3.61327e+06
# SG       | 3.11245e+06

# %% [markdown]
# # Classifying by multiple variables

# %%
more_cones = Table().with_columns(
    'Flavor', make_array('strawberry', 'chocolate', 'chocolate', 'strawberry', 'chocolate', 'bubblegum'),
    'Color', make_array('pink', 'light brown', 'dark brown', 'pink', 'dark brown', 'pink'),
    'Price', make_array(3.55, 4.75, 5.25, 5.25, 5.25, 4.75)
)

more_cones
# Out:
# Flavor     | Color       | Price
# strawberry | pink        | 3.55
# chocolate  | light brown | 4.75
# chocolate  | dark brown  | 5.25
# strawberry | pink        | 5.25
# chocolate  | dark brown  | 5.25
# bubblegum  | pink        | 4.75

# %%
# Can provide a list of multiple categories to group by
more_cones.group(['Flavor', 'Color'])
# Out:
# Flavor     | Color       | count
# bubblegum  | pink        | 1
# chocolate  | dark brown  | 2
# chocolate  | light brown | 1
# strawberry | pink        | 2

# %%
# Just like with a single variable, you can provide 
# a function to look at a different characteristic
more_cones.group(['Flavor', 'Color'], max)
# Out:
# Flavor     | Color       | Price max
# bubblegum  | pink        | 4.75
# chocolate  | dark brown  | 5.25
# chocolate  | light brown | 4.75
# strawberry | pink        | 5.25

# %% [markdown]
# # Practice 3
# Find the total paid in salaries by each team *during each season*.
#
# - Select the columns relevant to your calculation.
# - Group by multiple columns in such a way that the sum is returned.

# %%
nba_team_season_salary = nba.select('team', 'season', 'salary')
salaries_by_season = nba_team_season_salary.group(['team', 'season'], sum)
salaries_by_season
# Out:
# team          | season | salary sum
# Atlanta Hawks | 2000   | 16018000
# Atlanta Hawks | 2001   | 19721000
# Atlanta Hawks | 2002   | 49862000
# Atlanta Hawks | 2003   | 54529000
# Atlanta Hawks | 2004   | 15724000
# Atlanta Hawks | 2005   | 10899000
# Atlanta Hawks | 2006   | 38198405
# Atlanta Hawks | 2007   | 45084224
# Atlanta Hawks | 2008   | 38116186
# Atlanta Hawks | 2009   | 68992109
# ... (648 rows omitted)
