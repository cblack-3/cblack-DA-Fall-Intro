# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
nba = Table.read_table('nba_salaries.csv')
warriors = nba.where('team', 'Golden State Warriors')

# %%
warriors
# Out:
# rank | name              | position | team                  | salary  | season
# 41   | Donyell Marshall  | PF       | Golden State Warriors | 5250000 | 2000
# 47   | Erick Dampier     | C        | Golden State Warriors | 4988000 | 2000
# 58   | Mookie Blaylock   | G        | Golden State Warriors | 4200000 | 2000
# 59   | Chris Mills       | SF       | Golden State Warriors | 4200000 | 2000
# 64   | Jason Caffey      | F        | Golden State Warriors | 3937000 | 2000
# 89   | Vonteego Cummings | PG       | Golden State Warriors | 2600000 | 2000
# 92   | Antawn Jamison    | PF       | Golden State Warriors | 2503000 | 2000
# 73   | Erick Dampier     | C        | Golden State Warriors | 5611000 | 2001
# 91   | Mookie Blaylock   | G        | Golden State Warriors | 4800000 | 2001
# 92   | Chris Mills       | SF       | Golden State Warriors | 4800000 | 2001
# ... (301 rows omitted)

# %%
salary_select = warriors.select('salary')
salary_select

# %%
type(salary_select)
# Returns a column in a table format

# %%
salary_col = warriors.column('salary')
salary_col

# %%
type(salary_col)

# %%
#np.average(salary_select)
# can't call numpy function on tables

# %%
np.average(salary_col)

# %% [markdown]
# ## Practice
#
# Find the total salary paid to Chicago Bulls players in the year 2010.
# - Use where to narrow the table to the right team and year.
# - Use column to extract the correct column as an array.
# - Use the sum command on the array.

# %%
bulls = nba.where('team', 'Chicago Bulls')
bulls2010 = bulls.where('season', 2010)
#bulls2010.show()
salary_arr = bulls2010.column('salary')
np.average(salary_arr)

# %% [markdown]
# ## with_column

# %%
nba = Table.read_table('nba_salaries.csv')
warriors = nba.where('team', 'Golden State Warriors')
warriors.show(10)

# %%
salary_dollars = warriors.column('salary')
salary_euros = np.round(0.86 * salary_dollars)
salary_euros

# %%
# Attach new column to table
warriors = warriors.with_column('salary euros', salary_euros)
warriors.show(10) # salaries turned from into to float, but that's okay
