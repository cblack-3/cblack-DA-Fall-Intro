# %%
from datascience import *
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
plots.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# # Bar Charts
#
# Useful when the input variable is categorical and the output is the frequency of each category.

# %%
# The flavor of ice cream is a categorical variable 
# The count of 
icecream = Table().with_columns(
    'Flavor', make_array('Chocolate', 'Strawberry', 'Vanilla'),
    'Number of Cartons', make_array(16, 5, 9)
)
icecream
# Out:
# Flavor     | Number of Cartons
# Chocolate  | 16
# Strawberry | 5
# Vanilla    | 9

# %%
icecream.barh('Flavor', 'Number of Cartons')
# or simply
#icecream.barh('Flavor')

# %%
# Even better if you sort first
icecream = icecream.sort('Number of Cartons', descending = True)
icecream.barh('Flavor')

# %% [markdown]
# # Practice
# Plot the ten movies with the *lowest* adjusted gross as a bar chart.
# The category is the name of the movie.
# The "frequencies" are the adjusted gross.
#
# * Sort in such a way that the lowest gross is on top.
# * Use take() to get the top ten rows in a new table.
# * Call barh on the new table.

# %%
# Highest grossing movies as of 2017
top_movies = Table.read_table('top_movies_2017.csv')
top_movies
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973
# Snow White and the Seven Dwarves | Disney          | 184925486 | 969010000        | 1937
# ... (190 rows omitted)

# %%
sorted_top_movies = top_movies.sort('Gross (Adjusted)', descending = True)
lowest_ten = sorted_top_movies.take(np.arange(10))
lowest_ten.barh('Title', 'Gross (Adjusted)')

# %% [markdown]
# # Grouping

# %%
top_movies
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973
# Snow White and the Seven Dwarves | Disney          | 184925486 | 969010000        | 1937
# ... (190 rows omitted)

# %%
# group counts how many times a particular category appears in your data set
studio_distribution = top_movies.group('Studio')
studio_distribution
# Out:
# Studio      | count
# AVCO        | 1
# Buena Vista | 35
# Columbia    | 9
# Disney      | 11
# Dreamworks  | 3
# Fox         | 24
# IFC         | 1
# Lionsgate   | 3
# MGM         | 7
# Metro       | 1
# ... (13 rows omitted)

# %%
# Grouped data is perfect for a bar chart.
studio_distribution = studio_distribution.sort('count', descending = True)
studio_distribution.barh('Studio')
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Studio</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Buena Vista    </td> <td>35   </td>
#         </tr>
#         <tr>
#             <td>Warner Brothers</td> <td>29   </td>
#         </tr>
#         <tr>
#             <td>Paramount      </td> <td>25   </td>
#         </tr>
#         <tr>
#             <td>Fox            </td> <td>24   </td>
#         </tr>
#         <tr>
#             <td>Universal      </td> <td>23   </td>
#         </tr>
#         <tr>
#             <td>Disney         </td> <td>11   </td>
#         </tr>
#         <tr>
#             <td>Columbia       </td> <td>9    </td>
#         </tr>
#         <tr>
#             <td>MGM            </td> <td>7    </td>
#         </tr>
#         <tr>
#             <td>United Artists </td> <td>6    </td>
#         </tr>
#         <tr>
#             <td>Newline        </td> <td>5    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # Practice
# Group the movies in top_movies by release year and plot the resulting frequencies.

# %%
top_movies_release_year = top_movies.group('Year')
top_movies_release_year = top_movies_release_year.sort('count', descending = True)
top_movies_release_year.barh('Year')

# %% [markdown]
# # Binning
# Lets put the movies into five-year bins and plot again.

# %%
# Generate 10 equally spaced bins, but it's not great for a variable like Year
auto_binned_movies = top_movies.bin('Year', bins = 10)
auto_binned_movies.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Year count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1921  </td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1930.6</td> <td>3         </td>
#         </tr>
#         <tr>
#             <td>1940.2</td> <td>6         </td>
#         </tr>
#         <tr>
#             <td>1949.8</td> <td>13        </td>
#         </tr>
#         <tr>
#             <td>1959.4</td> <td>18        </td>
#         </tr>
#         <tr>
#             <td>1969  </td> <td>26        </td>
#         </tr>
#         <tr>
#             <td>1978.6</td> <td>24        </td>
#         </tr>
#         <tr>
#             <td>1988.2</td> <td>28        </td>
#         </tr>
#         <tr>
#             <td>1997.8</td> <td>40        </td>
#         </tr>
#         <tr>
#             <td>2007.4</td> <td>41        </td>
#         </tr>
#         <tr>
#             <td>2017  </td> <td>0         </td>
#         </tr>
#     </tbody>
# </table>

# %%
# Use arange to create specific bins
max_year = max(top_movies.column('Year'))
min_year = min(top_movies.column('Year'))
print(min_year, max_year)
# Out:
# 1921 2017

# %%
# Creates an array starting at 1921, ending at 2018, and counts by 9s
year_bins = np.arange(1921, 2018, 9)
year_bins
# Out:
# array([1921, 1930, 1939, 1948, 1957, 1966, 1975, 1984, 1993, 2002, 2011])

# %%
# Appears to have no movies released after 2011 because the last bin is always empty.
manual_binned_movies = top_movies.bin('Year', bins = year_bins)
manual_binned_movies.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Year count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1921</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1930</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1939</td> <td>8         </td>
#         </tr>
#         <tr>
#             <td>1948</td> <td>10        </td>
#         </tr>
#         <tr>
#             <td>1957</td> <td>16        </td>
#         </tr>
#         <tr>
#             <td>1966</td> <td>20        </td>
#         </tr>
#         <tr>
#             <td>1975</td> <td>22        </td>
#         </tr>
#         <tr>
#             <td>1984</td> <td>25        </td>
#         </tr>
#         <tr>
#             <td>1993</td> <td>30        </td>
#         </tr>
#         <tr>
#             <td>2002</td> <td>39        </td>
#         </tr>
#         <tr>
#             <td>2011</td> <td>0         </td>
#         </tr>
#     </tbody>
# </table>

# %%
# We can fix it by making sure the last number incorporates our max year.
year_bins = np.arange(1921, 2021, 9)
manual_binned_movies = top_movies.bin('Year', bins = year_bins)
manual_binned_movies.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Year count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1921</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1930</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1939</td> <td>8         </td>
#         </tr>
#         <tr>
#             <td>1948</td> <td>10        </td>
#         </tr>
#         <tr>
#             <td>1957</td> <td>16        </td>
#         </tr>
#         <tr>
#             <td>1966</td> <td>20        </td>
#         </tr>
#         <tr>
#             <td>1975</td> <td>22        </td>
#         </tr>
#         <tr>
#             <td>1984</td> <td>25        </td>
#         </tr>
#         <tr>
#             <td>1993</td> <td>30        </td>
#         </tr>
#         <tr>
#             <td>2002</td> <td>37        </td>
#         </tr>
#         <tr>
#             <td>2011</td> <td>30        </td>
#         </tr>
#         <tr>
#             <td>2020</td> <td>0         </td>
#         </tr>
#     </tbody>
# </table>

# %%
year_bins
# Out:
# array([1921, 1930, 1939, 1948, 1957, 1966, 1975, 1984, 1993, 2002, 2011,
#        2020])

# %%
manual_binned_movies.barh('bin')

# %% [markdown]
# # Practice
# Find reasonable bin sizes for adjusted gross. Aim for ten or so nonempty bins.
# Bin the data and plot the resulting frequencies.
#
# * Use min and max to find a good lower and upper bound for the bins.
# * Experiment with bin sizes until you have about ten or so bins.
# * Use the bin function create a new binned table.
# * Call barh on the new table.

# %%
gross_adjusted_max = max(top_movies.column('Gross (Adjusted)'))
gross_adjusted_min = min(top_movies.column('Gross (Adjusted)'))
print(gross_adjusted_min, gross_adjusted_max)
# Out:
# 338409100 1796176700

# %%
gross_adj = np.arange(gross_adjusted_min, gross_adjusted_max + 150000000, 150000000)
gross_adj = top_movies.bin('Gross (Adjusted)', bins = gross_adj)
gross_adj.show()
gross_adj.barh('bin')
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Gross (Adjusted) count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>338409100 </td> <td>119                   </td>
#         </tr>
#         <tr>
#             <td>488409100 </td> <td>48                    </td>
#         </tr>
#         <tr>
#             <td>638409100 </td> <td>13                    </td>
#         </tr>
#         <tr>
#             <td>788409100 </td> <td>9                     </td>
#         </tr>
#         <tr>
#             <td>938409100 </td> <td>3                     </td>
#         </tr>
#         <tr>
#             <td>1088409100</td> <td>4                     </td>
#         </tr>
#         <tr>
#             <td>1238409100</td> <td>2                     </td>
#         </tr>
#         <tr>
#             <td>1388409100</td> <td>0                     </td>
#         </tr>
#         <tr>
#             <td>1538409100</td> <td>1                     </td>
#         </tr>
#         <tr>
#             <td>1688409100</td> <td>1                     </td>
#         </tr>
#         <tr>
#             <td>1838409100</td> <td>0                     </td>
#         </tr>
#     </tbody>
# </table>
