# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
imdb = Table.read_table('imdb.csv')
imdb.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Votes</th> <th>Rating</th> <th>Title</th> <th>Year</th> <th>Decade</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>88355 </td> <td>8.4   </td> <td>M                  </td> <td>1931</td> <td>1930  </td>
#         </tr>
#         <tr>
#             <td>132823</td> <td>8.3   </td> <td>Singin' in the Rain</td> <td>1952</td> <td>1950  </td>
#         </tr>
#         <tr>
#             <td>74178 </td> <td>8.3   </td> <td>All About Eve      </td> <td>1950</td> <td>1950  </td>
#         </tr>
#         <tr>
#             <td>635139</td> <td>8.6   </td> <td>Léon               </td> <td>1994</td> <td>1990  </td>
#         </tr>
#         <tr>
#             <td>145514</td> <td>8.2   </td> <td>The Elephant Man   </td> <td>1980</td> <td>1980  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (245 rows omitted)</p>

# %% [markdown]
# # Question 1
# Find the ten movies released in the year 2000 or later with the highest number of votes according to imdb.csv. Format your answer as a table with columns Title and Votes (in that order) of the three requested movies.

# %%
movies_2000 = imdb.where('Year', are.above_or_equal_to(2000)) 
movies_sorted = imdb.sort('Year', descending = True)
top_movies = movies_sorted.take(np.arange(0,10,1))
movies_title_votes = top_movies.select('Title','Votes')
movies_title_votes.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Title</th> <th>Votes</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Inside Out (2015/I)       </td> <td>79615 </td>
#         </tr>
#         <tr>
#             <td>Mad Max: Fury Road        </td> <td>262425</td>
#         </tr>
#         <tr>
#             <td>Gone Girl                 </td> <td>441174</td>
#         </tr>
#         <tr>
#             <td>Relatos salvajes          </td> <td>46987 </td>
#         </tr>
#         <tr>
#             <td>X-Men: Days of Future Past</td> <td>427099</td>
#         </tr>
#         <tr>
#             <td>The Imitation Game        </td> <td>321834</td>
#         </tr>
#         <tr>
#             <td>Interstellar              </td> <td>689541</td>
#         </tr>
#         <tr>
#             <td>Guardians of the Galaxy   </td> <td>527349</td>
#         </tr>
#         <tr>
#             <td>The Grand Budapest Hotel  </td> <td>369141</td>
#         </tr>
#         <tr>
#             <td>Whiplash                  </td> <td>264333</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # Question 2
#
# Create a table with columns Title and Votes containing all movies released in 1999.
#
# Next, attach a new column to the table called Percent Votes that contains the percent of votes each movie received when considered among all votes cast for movies released in 1999.
#
# For example, if the total number of votes cast for movies released in 1999 is 200 and "The Matrix" received 30 of them, then the column Percent Votes corresponding to "The Matrix" should 15.

# %%
movies_1999 = imdb.where('Year', 1999)
title_votes_1999 = movies_1999.select('Title', 'Votes')
votes_1999_array = title_votes_1999.column('Votes')
sum_votes_1999 = sum(votes_1999_array)
percent_votes = votes_1999_array / sum_votes_1999
final_table = title_votes_1999.with_column('Percent Votes', percent_votes)
final_table
# Out:
# Title           | Votes   | Percent Votes
# Fight Club      | 1177098 | 0.274441
# American Beauty | 735056  | 0.171379
# The Sixth Sense | 630994  | 0.147117
# The Matrix      | 1073043 | 0.250181
# The Green Mile  | 672878  | 0.156882
